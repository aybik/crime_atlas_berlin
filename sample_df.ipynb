# %%
import pandas as pd
df = pd.read_csv("data/berlin_crime_final.csv")

# %%
df = df.head(750)

# %%
df
# Out:
#       LOR_ID                      Bezirk            Bezirksregion  \
# 0    11001.0                       Mitte           Tiergarten Süd
# 1    11002.0                       Mitte        Regierungsviertel
# 2    11003.0                       Mitte           Alexanderplatz
# 3    11004.0                       Mitte        Brunnenstraße Süd
# 4    12005.0                       Mitte              Moabit West
# ..       ...                         ...                      ...
# 745  36013.0                      Pankow           Helmholtzplatz
# 746  36014.0                      Pankow      Prenzlauer Berg Ost
# 747  37015.0                      Pankow  Prenzlauer Berg Südwest
# 748  37016.0                      Pankow      Prenzlauer Berg Süd
# 749  41001.0  Charlottenburg-Wilmersdorf      Charlottenburg Nord
#
#                                              CrimeType  Fallzahl  year  \
# 0                                 Straftaten insgesamt      5475  2015
# ...

# %%
df.to_csv("sample_data.csv", index=False)
